# %% [markdown]
# ## Problem Sloving And Programming
# ## charishma.G
# ## 221710308020
# ## Day 14
# ## 17-05-2019
# ## Day Outcomes
# * Objective 1
# * Objective 2
# * Objective 3

# %% [markdown]
# ## problem 1
# ## problem statement
# define a function to read from a csv file using pandas Display the csv file as output
# ## Test cases
# * test case1
# * test case2
# *test cases3

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('datafiles/income.csv')
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
# 5  04000US07     Chicago   -999   -999   -999   -999   -999   -999   -999
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528
# 5   -999   -999

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
df=readcsv('datafiles/income.csv')
df.columns
for row in df.values:
    print('geoID:',row[0],'state;',row[1])
# Out:
# geoID: 04000US01 state; Alabama
# geoID: 04000US02 state; Alaska
# geoID: 04000US04 state; Arizona
# geoID: 04000US05 state; Arkansas
# geoID: 04000US06 state; California
# geoID: 04000US07 state; Chicago

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('datafiles/income.csv')
df.columns
df.tail(3)
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
# 5  04000US07     Chicago   -999   -999   -999   -999   -999   -999   -999
#
#     2012   2013
# 3  39018  39919
# 4  57020  57528
# 5   -999   -999

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('datafiles/income.csv')
df.columns
df.head(4)
# Out:
#        GEOID     State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01   Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02    Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04   Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05  Arkansas  36658  37057  40795  39586  36538  38587  41302
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('datafiles/income.csv')
df.columns
df.iat[1,6]
# Out:
# 61604

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('datafiles/income.csv')
df.columns
df.loc[0]
# Out:
# GEOID    04000US01
# State      Alabama
# 2005         37150
# 2006         37952
# 2007         42212
# 2008         44476
# 2009         39980
# 2010         40933
# 2011         42590
# 2012         43464
# 2013         41381
# Name: 0, dtype: object

# %%
import pandas as pd
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('datafiles/income.csv')
df.columns
df.loc[2][0]
# Out:
# '04000US04'

# %% [markdown]
# ## problem 2
# ## problem statement
# define a function to add new data to csv file

# %%
def addrowcsv(filename,rowdata):
    df=readcsv(filename)
    df.loc[len(df)]=rowdata
    df.to_csv(filename)
    return df
rowdata=['010101','statename',123,4325,4565,9084,8675,9876,4567,8976,9631]
addrowcsv('datafiles/income.csv',rowdata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f065b4720728> in <module>
#       5     return df
#       6 rowdata=['010101','statename',123,4325,4565,9084,8675,9876,4567,8976,9631]
# ----> 7 addrowcsv('datafiles/income.csv',rowdata)
#
# <ipython-input-24-f065b4720728> in addrowcsv(filename, rowdata)
#       1 def addrowcsv(filename,rowdata):
#       2     df=readcsv(filename)
# ----> 3     df.loc[len(df)]=rowdata
#       4     df.to_csv(filename)
#       5     return df
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     443                         if is_list_like_indexer(value):
#     444                             if len(value) != len(self.obj.columns):
# --> 445                                 raise ValueError("cannot set a row with "
#     446                                                  "mismatched columns")
#     447
#
# ValueError: cannot set a row with mismatched columns

# %%
def updaterowcsv(filename, rowindex, rowdata):
    df = readcsv(filename)
    df.loc[rowindex] = rowdata
    df.to_csv(filename, index=False)
    return df

rowdata = ['04000US08','florida',123,4325,4565,9084,83123,423,987,345,765]
updaterowcsv('datafiles/income.csv', 6, rowdata)

#df = df.drop('Unnamed: 0', axis=1)
#readCSV('DataFiles/Income.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-03807e244eb7> in <module>
#       6
#       7 rowdata = ['04000US08','florida',123,4325,4565,9084,83123,423,987,345,765]
# ----> 8 updaterowcsv('datafiles/income.csv', 6, rowdata)
#       9
#      10 #df = df.drop('Unnamed: 0', axis=1)
#
# <ipython-input-31-03807e244eb7> in updaterowcsv(filename, rowindex, rowdata)
#       1 def updaterowcsv(filename, rowindex, rowdata):
#       2     df = readcsv(filename)
# ----> 3     df.loc[rowindex] = rowdata
#       4     df.to_csv(filename, index=False)
#       5     return df
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     609
#     610                     if len(labels) != len(value):
# --> 611                         raise ValueError('Must have equal len keys and value '
#     612                                          'when setting with an iterable')
#     613
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
def addrowcsv(filename, rowdata):
    df = readcsv(filename) # Get dataframe from CSV
    df.loc[len(df)] = rowdata # Add a row to the dataframe
    df.to_csv(filename, index=False)
    return df

rowdata = ['010101', 'statename', 123, 4325, 4565, 9084, 83123, 423, 987, 345, 765]
addrowcsv('datafiles/income.csv', rowdata)
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
# 5  04000US07     Chicago   -999   -999   -999   -999   -999   -999   -999
# 6     010101   statename    123   4325   4565   9084   8675   9876   4567
# 7     010101   statename    123   4325   4565   9084  83123    423    987
# 8     010101   statename    123   4325   4565   9084  83123    423    987
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528
# 5   -999   -999
# 6   8976   9631
# 7    345    765
# 8    345    765

# %%
def deleterowcsv(filename,rowindex):
    df=readcsv(filename)
    df=df.drop(rowindex)
    df.to_csv(filename,index=False)
    return df
df=df.
# Out:
#   File "<ipython-input-38-6e722baa744b>", line 6
#     df=df.
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## problem 5
# ## p

# %%
def addmarksdatacsv(marksfile,nr,scroll):
# Out:
#   File "<ipython-input-39-74a44adf039b>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
