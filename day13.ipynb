# %% [markdown]
# ##  Problem Sloving And Programming
# ## charishma.G
# ## 221710308020
# ## Day 13
# ## 16-05-2019
# ## Day Outcomes
# * Objective 1
# * Objective 2
# * Objective 3

# %% [markdown]
# ## problem 1
# ## problem statement
# password validation
# ## Test cases
# * should contain atleast one upper case letter
# * length in range(6,21)
# * should contain atleast one special case letter
# * should start with upper case or ;ower case
# * should contain atleast one digit

# %%
import re
pattern='^[A-Za-z][a-zA-Z][0-9]+[@!#$%^&*]+{5,21}$'
domain='chowdarY@26'
if re.match(pattern,domain):
    print('match')
else:
    print('dont match')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-5e693e0d1298> in <module>
#       2 pattern='^[A-Za-z][a-zA-Z][0-9]+[@!#$%^&*]+{5,21}$'
#       3 domain='chowdarY@26'
# ----> 4 if re.match(pattern,domain):
#       5     print('match')
#       6 else:
#
# ~\Anaconda3\lib\re.py in match(pattern, string, flags)
#     171     """Try to apply the pattern at the start of the string, returning
#     172     a Match object, or None if no match was found."""
# --> 173     return _compile(pattern, flags).match(string)
#     174
#     175 def fullmatch(pattern, string, flags=0):
#
# ~\Anaconda3\lib\re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
#     287     if not (flags & DEBUG):
# ...

# %% [markdown]
# ## problem 2
# ### problem statement
# define function to read data from text file
# ## test cases
# * test case1
# * test cases2
# * test cases3

# %%
def readfiledata(filename):
    f=open(filename,'r')
    filedata=f.readline()
    f.close()
    return filedata
readfiledata('data files/data.txt')
# Out:
# 'data in line 1\n'

# %%
def readfiledata(filename):
    with open (filename,'r') as f:
        print(f.read())
        return
    readfiledata('data files/data.txt')

# %%
def writeintofile(filename,data):
    with open(filename,'w') as f:
        f.write(data)
    return
writeintofile('data files/fileswrite.txt','data')

# %%
def readfiledata(filename):
    f=open(filename,'r')
    filedata=f.read()
    f.close()
    return filedata

# %%
import random
def genmarks(n,filename):
    with open(filename,'w')as marksfile:
        for i in range(0,n):
            marks=random.randint(0,101)
            marksfile.write(str(marks)+'\n')
            return 
        genmarks(100,'data files/marksdata.txt')

# %% [markdown]
# ## problem 2
# ## problem statement
# define a function to generate a marks data file for 1300 students such that each marks is entred in new line marks range from 0-100(inclusive) as random numbers
# * highest marks
# * lowest marks
# * average marks
# * no of students with distinction(>80)
# * no of students with first class (>60)
# * no of students with secound class (>50)
# * no of students with third class(>40)
# * no of students failed(>40)

# %%
import random
list=[]
import random
def genmarks(n,filename):
    with open(filename,'r') as markslist:
        for i in range (0,n):
# Out:
#   File "<ipython-input-13-dc5179a71cea>", line 7
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def readlist(filename):
    li=[]
    with open(filename,'r')as f:
        for line in f:
            li.append(int(line))
            print(li)
    maximum=max(li)
    minimum=min(li)
    print("highest=",maximum)
    print("lower=",minimum)    
    print("average=",(maximum+minimum)/2)
    dis=0
    fc=0
    sc=0
    tc=0
    fail=0
    for i in range(0,1300):
        if li[i]>80:
            dist+=1
        elif li[i]>60:
            fc+=1
        elif li[i]>50:
            sc+=1
        elif li[i]>40:
            tc+=1
        else:
            fail+=1
        print("number of distinction students(>80)=",dis)
        print("number of first class students(>60)=",fc)
readlist('data files/marksdata.txt')
# Out:
# [6]
# [6, 4]
# [6, 4, 40]
# [6, 4, 40, 26]
# [6, 4, 40, 26, 59]
# [6, 4, 40, 26, 59, 11]
# [6, 4, 40, 26, 59, 11, 36]
# [6, 4, 40, 26, 59, 11, 36, 2]
# [6, 4, 40, 26, 59, 11, 36, 2, 28]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84, 54]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84, 54, 48]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84, 54, 48, 85]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84, 54, 48, 85, 53]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84, 54, 48, 85, 53, 20]
# [6, 4, 40, 26, 59, 11, 36, 2, 28, 16, 12, 34, 41, 7, 84, 54, 48, 85, 53, 20, 4]
# ...

# %%
import timeit
def square
